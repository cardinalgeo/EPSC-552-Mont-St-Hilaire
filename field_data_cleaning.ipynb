# %%
import pandas as pd

# %%
data = pd.read_excel('./data/raw/Field_data.xlsx')

data.head()
# Out:
# /Users/robertcollar/miniconda3/envs/EPSC-552-Mont-St-Hilaire/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#   wkt_geom         UTM-EW        UTM-NS Group                 Date Weather  \
# 0    Point  643901.071880  5.044402e+06     1  2021-09-24 00:00:00    Rain
# 1    Point  643858.740795  5.044593e+06     1              9/24/21    Rain
# 2    Point  643873.996064  5.044791e+06     1              9/24/21    Rain
# 3    Point  643709.451179  5.044921e+06     1  2021-09-24 00:00:00    Rain
# 4    Point  643877.208886  5.045003e+06     1  2021-09-24 00:00:00    Rain
#
#   SampleID      Type  River orde  Discharge  ...  EC (uS/cm)  T(C)  \
# 0   GR-001      Soil         NaN        NaN  ...         NaN   NaN
# 1   GR-002      Soil         NaN        NaN  ...         NaN   NaN
# 2   GR-003      Soil         NaN        NaN  ...         NaN   NaN
# ...
